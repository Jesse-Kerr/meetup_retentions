# %% [markdown]
# # Meetup Project
#
#
# What is in a Meetup API request?
#
# 1. https://api.meetup.com: The API host.
# 2. /find/groups: The method
# 3. zip=11211&radius=1&category=25: The args. Here is where you may add the API key.
#     From what I can tell, the only args you can give are zip, radius, and category. So maybe you need to go through the zips
# 4. &order=members:  How to order the results.
#
# * To find last event in the list: db.events.find().limit(1).sort({$natural:-1})

# %% [markdown]
# # Imports / Pymongo Setup

# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import requests
import json
import warnings
import time
from pprint import pprint
warnings.filterwarnings('ignore')
key = open('api.txt', 'r').read()

client = MongoClient('localhost', 27017)
db = client.meet_up
collection = db.groups
events_coll = db.events
attendees = db.attendees
categories = db.category_per_group

# %% [markdown]
# ## Get number of groups in each category globally

# %%
# This creates a list of dictionaries, with name, sort_name, id, and shortname. 
dict_categories = json.loads(requests.get('https://api.meetup.com/2/categories?key={}'.format(key)).text)['results']
dict_categories
#There are 33 total categories. 

#make list of ids 
ids = [item['id'] for item in dict_categories]
ids.sort()

#define function
def get_count_of_category(number):
    req_count = requests.get('https://api.meetup.com/find/groups?key={}&radius=global&category={}'.format(key, number))\
                        .headers['X-Total-Count']
    cat_name = next(item['name'] for item in dict_categories if item["id"] == number)
    return [number, int(req_count), cat_name]
    
groups_per_category = [get_count_of_category(category) for category in ids]

groups_per_category
# Out:
# [[1, 7121, 'Arts & Culture'],
#  [2, 51358, 'Career & Business'],
#  [3, 2038, 'Cars & Motorcycles'],
#  [4, 7464, 'Community & Environment'],
#  [5, 4949, 'Dancing'],
#  [6, 9446, 'Education & Learning'],
#  [8, 1503, 'Fashion & Beauty'],
#  [9, 8248, 'Fitness'],
#  [10, 10116, 'Food & Drink'],
#  [11, 7828, 'Games'],
#  [12, 4365, 'LGBT'],
#  [13, 5213, 'Movements & Politics'],
#  [14, 27552, 'Health & Wellbeing'],
#  [15, 4041, 'Hobbies & Crafts'],
#  [16, 14164, 'Language & Ethnic Identity'],
#  [17, 1485, 'Lifestyle'],
#  [18, 4325, 'Book Clubs'],
#  [20, 3509, 'Movies & Film'],
#  [21, 7129, 'Music'],
#  [22, 17399, 'New Age & Spirituality'],
#  [23, 14562, 'Outdoors & Adventure'],
#  [24, 405, 'Paranormal'],
#  [25, 6960, 'Parents & Family'],
#  [26, 2555, 'Pets & Animals'],
#  [27, 3884, 'Photography'],
#  [28, 6302, 'Religion & Beliefs'],
#  [29, 1392, 'Sci-Fi & Fantasy'],
#  [30, 2387, 'Singles'],
#  [31, 23091, 'Socializing'],
#  [32, 9920, 'Sports & Recreation'],
#  [33, 6992, 'Support'],
#  [34, 64458, 'Tech'],
#  [36, 3507, 'Writing']]

# %%
#Total number of groups

sum([val[1] for val in groups_per_category])
# Out:
# 345668

# %% [markdown]
# I find 344,607 groups globally. Wow!

# %% [markdown]
# # Download all Meetup Groups

# %%
#Meetup only allows 200 requests at a time.
def get_groups_for_category(number):
    number_of_groups = [entry[1] for entry in groups_per_category if entry[0] == number] 
    offsets = list(range(int(number_of_groups[0]/200) + 1))
    for offset in offsets:
        req = requests.get('https://api.meetup.com/find/groups?key={}\
                            &category={}&radius=global&\
                            &offset={}&page=200'.format(key, number, offset))
        json_data = json.loads(req.text)
        collection.insert_many(json_data)

#list of all categories 
categories = [number[0] for number in groups_per_category if number[0] != 24]

for number in categories:
    get_groups_for_category(number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-1cd6b1ff4096> in <module>
#      11
#      12 #list of all categories
# ---> 13 categories = [number[0] for number in groups_per_category if number[0] != 24]
#      14
#      15 for number in categories:
#
# NameError: name 'groups_per_category' is not defined

# %% [markdown]
# # Visibilities
#
# 88% of the groups are public, 12% are public_limited, and 0.3% are members.
#
# Public_limited allows you to see the events, but not who went. Members does not allow you to even see the events.
# Thus, these groups both need to be deleted.

# %%
def percent_each_visibility(collection):
    visibilities = collection.distinct('visibility')
    total_count = collection.count()
    percentages = [[option, round(collection.find({'visibility': option}).count() / total_count, 3) * 100] for option in visibilities]
    return percentages

#Remove these visibilities from meetups.

collection.delete_many({'visibility' : {'$in' : ['public_limited', 'members']}})

percent_each_visibility(collection)
# Out:
# [['public', 100.0]]

# %% [markdown]
# # Download the events for a particular group

# %%
req = requests.get('https://api.meetup.com/Florida-MUFON-UFO-Research-and-Investigations/events?\
                    key={}&status=past'.format(key))

print(req.headers['X-Total-Count'])
pprint(json.loads(req.text)[0])
# Out:
# 168
# {'created': 1351348658000,
#  'date_in_series_pattern': False,
#  'description': '<p>\xa0</p> <p>\xa0</p> <p>\xa0</p> <p>\xa0</p> <p>\xa0</p> '
#                 "<p>Our FIRST MUFON Meetup \xa0will be at <b>Mimi's "
#                 'Cafe</b></p> <p>at the Avenues in Viera, FL. \xa0From 5:30 pm '
#                 'to 8:30 pm.</p> <p>\xa0</p> <p>Please RSVP for this meeting '
#                 'and all future meetings.</p> <p>Feel free to bring a friend '
#                 'or two. See you there!</p> <p>\xa0</p> <p>Your Host for the '
#                 'evening will be</p> <p><b>MUFON</b> Assistant State Director '
#                 'Teri Lynge</p> ',
#  'duration': 10800000,
#  'group': {'country': 'us',
#            'created': 1351346689000,
#            'id': 5582872,
#            'join_mode': 'open',
#            'lat': 27.969999313354492,
#            'localized_location': 'Palm Bay, FL',
#            'lon': -80.6500015258789,
#            'name': 'Florida MUFON UFO Research and Investigations',
#            'region': 'en_US',
#            'state': 'FL',
#            'timezone': 'US/Eastern',
#            'urlname': 'Florida-MUFON-UFO-Research-and-Investigations',
#            'who': 'UFOlogists'},
#  'how_to_find_us': 'Map provided',
#  'id': '88793112',
#  'link': 'https://www.meetup.com/Florida-MUFON-UFO-Research-and-Investigations/events/88793112/',
#  'local_date': '2012-12-06',
#  'local_time': '17:30',
#  'manual_attendance_count': 12,
#  'name': "Meeting on December 6th, 2012, Mimi's Cafe at the Avenues in Viera.",
#  'status': 'past',
#  'time': 1354833000000,
#  'updated': 1354995467000,
#  'utc_offset': -18000000,
#  'venue': {'address_1': '6630 Colonnade Avenue',
#            'city': 'Melbourne',
#            'country': 'us',
#            'id': 960032,
#            'lat': 28.247121810913086,
#            'localized_country_name': 'USA',
#            'lon': -80.72822570800781,
#            'name': "Mimi's Cafe",
#            'phone': '321-638-0404',
#            'repinned': False,
#            'state': 'FL',
#            'zip': '32940'},
#  'visibility': 'public',
#  'waitlist_count': 0,
#  'yes_rsvp_count': 15}

# %% [markdown]
# # Download all the events... ever

# %%
def get_all_events(collection):
    
    ''' 
    Download the events for a particular group. If there are more than 200 events, split the request by the dates of 
    event. Save into meetups.events
    '''
    
    urlnames = [entry['urlname'] for entry in collection.find()]
    for urlname in urlnames:
        # First, we need the total number of events for the group
        req = requests.get('https://api.meetup.com/{}/events?\
                            key={}&status=past&page=200&desc=true'.format(urlname, key))
        number_of_events = int(req.headers['X-Total-Count'])
        # Only deal with groups with no events
        if number_of_events != 0:
        # Insert the 200, then get the date of the last one.         
            while number_of_events > 200:
                json_data = json.loads(req.text)
                events_coll.insert_many(json_data)
                last_tmstp = "{}T{}".format(json_data[-1]['local_date'],json_data[-1]['local_time'])            
                req = requests.get('https://api.meetup.com/{}/events?\
                                key={}&status=past&page=200&desc=true&no_later_than={}'.format(urlname, key, last_tmstp))
                number_of_events -= 200
            # If less than 200, insert
            json_data = json.loads(req.text)
            events_coll.insert_many(json_data)
            print('Inserted {} into db.events!'.format(urlname))

get_all_events(collection)
# Out:
# Inserted Florida-MUFON-UFO-Research-and-Investigations into db.events!
# Inserted TheCenterNH into db.events!
# Inserted Colorado-MUFON into db.events!
# Inserted ufor-asn-au into db.events!
# Inserted inspiredghosttracking into db.events!
# Inserted BoulderEXO into db.events!
# Inserted LA-UFO-Channel into db.events!
# Inserted In-Search-of-the-Paranormal into db.events!
# Inserted MUFON-Georgia-Meetup into db.events!
# Inserted Exploring-The-Paranormal into db.events!
# Inserted Winnipeg-UFO-Research-and-Experiencers-Group into db.events!
# Inserted CosmicGate into db.events!
# Inserted spookylondonpubs into db.events!
# Inserted san-diego-paranormal-eye into db.events!
# Inserted PNW-SASQUATCH-CIRCLE into db.events!
# Inserted The-Lemp-Mansion-Meetup-Group into db.events!
# Inserted Extraterrestrial-Contact-Network-by-GA-CE-5-Initoative into db.events!
# Inserted Central-AZ-IANDS into db.events!
# Inserted Rocklin-UFO into db.events!
# Inserted OPA-Oklahoma-Paranormal-Association into db.events!
# Inserted tampabayparanormalsociety into db.events!
# Inserted UFO-DISCLOSURE-NETWORK-NEW-YORK into db.events!
# Inserted OregonHaunts into db.events!
# Inserted Phoenix-MUFON into db.events!
# Inserted Houston-MUFON-Meetup-Group into db.events!
# Inserted Florida-MUFON into db.events!
# Inserted CF-Anomalies-Explorers-com into db.events!
# Inserted Twin-Cities-UFO-Research-and-Investigations-Meetup into db.events!
# Inserted MUFON-Orange-County into db.events!
# Inserted Nottingham-Esoteric-Mysteries into db.events!
# Inserted Greater-Chicagoland-UFO-Meetup-Group into db.events!
# Inserted riphunters into db.events!
# Inserted MUFON-Marin-Sonoma into db.events!
# Inserted UFO-Inquiring-Minds-Portland-Or into db.events!
# Inserted SheDMontfordSpiritualSeekers into db.events!
# Inserted UFO-Explorers into db.events!
# Inserted OKLAHOMA-CITY-UFO-MEETUP-GROUP into db.events!
# Inserted Nashville-Metaphysical-New-Age-and-Psychic-Meetup into db.events!
# Inserted Association-of-Paranormal-Study-Raleigh into db.events!
# Inserted Ghosts-and-Spirits-by-Inspired-Ghost-Tracking into db.events!
# Inserted Social-Misfits-Adventure-Friends into db.events!
# Inserted Exton-paranormal into db.events!
# Inserted Vancouver-UFO-Meetup-Peaceful-Contact into db.events!
# Inserted brisbaneufomeetup into db.events!
# Inserted Kansas-City-Paradigm-Shift-Support into db.events!
# Inserted Wisdom-of-theSpirit into db.events!
# Inserted Indiana-UFO-Paranormal-Research-Group into db.events!
# Inserted ghosts-26 into db.events!
# Inserted Psychic-Development-Classes into db.events!
# Inserted BostonParanormalInvestigators into db.events!
# Inserted Ancient-Aliens-Human-Origins-Meetup into db.events!
# Inserted Houston-Thrillseeker-s into db.events!
# Inserted Kindred-Spirits-Society into db.events!
# Inserted Columbus-UFO-Discussion-Group into db.events!
# Inserted Bismarck-Paranormal-Evidence-Meetup into db.events!
# Inserted Holtsville-UFO-ET-Phenomenon-Meetup into db.events!
# Inserted Oregonians-for-Science-and-Reason into db.events!
# Inserted Boston-Ufo-group into db.events!
# Inserted SeacoastParanormal into db.events!
# Inserted Tokyo-Ascension-Group into db.events!
# Inserted Austin-Skywatchers-First-Contact-Specialists into db.events!
# Inserted nssofnt into db.events!
# Inserted TulsaPayItForward into db.events!
# Inserted UtahGhostHunters into db.events!
# Inserted DGS-Detroit-Ghost-Stories into db.events!
# Inserted The-Rhine-In-Raleigh into db.events!
# Inserted Hamilton-UFO-and-Paranormal-Society into db.events!
# Inserted trueparanormal into db.events!
# Inserted MainLineMUFON-com into db.events!
# Inserted Interested-In-The-Paranormal-World into db.events!
# Inserted Bay-Area-Ghost-Hunters into db.events!
# Inserted Calgary-UFO-Seekers-Meetup-Human-Initiated-UFO-sightings into db.events!
# Inserted Tokyo-ET-Contact-Group into db.events!
# Inserted Aussiedownunder-Paranormal-Investigations into db.events!
# Inserted Gathering-of-the-Forces-of-Light into db.events!
# Inserted Lexington-Anomalists-Books-Brews-Meetup into db.events!
# Inserted Columbus-Paranormal-Meetup into db.events!
# Inserted Haunted-And-Paranormal-Exploration into db.events!
# Inserted Asheville-Paranormal-Enthusiasts into db.events!
# Inserted Dundee-UFO-Meetup into db.events!
# Inserted Reno-Paranormal-Group into db.events!
# Inserted FRINGEnewjersey into db.events!
# Inserted Real-Ghost-Encounters into db.events!
# Inserted Coldspotters-Greater-Vancouver-Ghost-Enthusiastss into db.events!
# Inserted roundtables-com into db.events!
# Inserted asylum-london into db.events!
# Inserted Afterlife-Discussions into db.events!
# Inserted Sydney-Exopolitics-Meetup into db.events!
# Inserted australianschoolofenergetics into db.events!
# Inserted Garland-Ghost-Tracking-Meetup into db.events!
# Inserted History-N-Mystery-Ghost-Tour into db.events!
# Inserted Cosmic-Disclosure into db.events!
# Inserted Santa-Fe-Horror-Film-Meetup into db.events!
# Inserted meetup-group-Stargate-Cosmos-ET-UFO-Contactee-Albuquerque into db.events!
# Inserted colorado-ghost-hunters-group into db.events!
# Inserted Charlotte-UFO-Meetup into db.events!
# Inserted Paranormal-Events-of-Utah into db.events!
# Inserted The-Other-Side-investigations-of-West-Palm-Beach into db.events!
# Inserted Just-Talk-One-on-One-Weird-Experience-Support-Group into db.events!
# Inserted Pittsburgh-Conspiracy-Cafe into db.events!
# Inserted Toronto-area-Psychic-Development-Meetup into db.events!
# Inserted MUFON-Delaware into db.events!
# Inserted California-Paranormal-Networking into db.events!
# Inserted Cherry-Hill-South-Jersey-Paranormal-Research into db.events!
# Inserted Avalon-Visions-Movie-Night into db.events!
# Inserted Psychic-Classes-and-UFO-Nightvision-Events-by-Tana-Newberry into db.events!
# Inserted K-E-P-R-I into db.events!
# Inserted New-England-Ghost-Projects-Paranormal-Study-Group into db.events!
# Inserted Portland-Crop-Circles-Meetup into db.events!
# Inserted Cosmic-Disclosure-Tacoma into db.events!
# Inserted Duncan-BC-UFO-and-Experiencers-Meetup into db.events!
# Inserted Weirdoes-r-Us into db.events!
# Inserted Delhi-and-bhangarh-haunted-place-meetup into db.events!
# Inserted paranormal-521 into db.events!
# Inserted AnomalyArchives into db.events!
# Inserted Austin-Ground-Crew-First-Contact-Enthusiasts into db.events!
# Inserted Austin-Paranormal-Research into db.events!
# Inserted Parasoul-Paranormal into db.events!
# Inserted Supernatural-Paranormal into db.events!
# Inserted SanAntonio-Paranormal-Meetup into db.events!
# Inserted Paranormal-Planet into db.events!
# Inserted Texas-investigators-of-the-paranormal-society-TIPS into db.events!
# Inserted Blue-Super-Moon-Ghost-Tour into db.events!
# Inserted Paranormal-Activity-Group into db.events!
# Inserted CE5-Ambassador-to-the-Universe into db.events!
# Inserted Hill-House-Manor into db.events!
# Inserted RESEARCH-INVESTIGATIONS-OF-THE-PARANORMAL-NEW-ORLEANS into db.events!
# Inserted Independence-County-Ghost-Society-ICGhostS into db.events!
# Inserted RIP-HUNTERS-RESEARCH-INVESTIGATIONS-OF-THE-PARANORMAL into db.events!
# Inserted Huntsville-Paranormal-Study-Center into db.events!
# Inserted stlghost into db.events!
# Inserted Illinois-Paranormal into db.events!
# Inserted MAPSGhost into db.events!
# Inserted S-A-G-E-Nebraska into db.events!
# Inserted Cottage-Hills-Ghost-Tracking-Meetup into db.events!
# Inserted En-la-fogata into db.events!
# Inserted Parapsicologia into db.events!
# Inserted Cosmic-Disclosure-Discussion into db.events!
# Inserted PRISM-Paranormal-Research into db.events!
# Inserted Tucson-Paranormal-Meetup into db.events!
# Inserted allies-of-humanity into db.events!
# Inserted IIG-Atlanta into db.events!
# Inserted Northern-Colorado-Sirius-Disclosure-CE-5-UFO-Contact-Meetup into db.events!
# Inserted Peoria-Paranormal-Meetup into db.events!
# Inserted Spirited-Minds-Paranormal-Seekers-Arizona into db.events!
# Inserted Clearwater-Paranormal-Meetup into db.events!
# Inserted Spinetinglers-Society into db.events!
# Inserted Florida-Psychic-and-Paranormal-Meetup into db.events!
# Inserted RIP-HUNTERS-PARANORMAL-FLORIDAS-WEST-COAST into db.events!
# Inserted ashevilleparanormalsociety into db.events!
# Inserted Haunted-church-in-Cicero into db.events!
# Inserted Haunted-church-in-Cicero-2 into db.events!
# Inserted McHenry-Paranormal-Evidence-Meetup into db.events!
# Inserted SAVANNAH-R-I-P-HUNTERS-PARANORMAL into db.events!
# Inserted In-the-City-of-Dark-Angels into db.events!
# Inserted Unexplained-Investigations into db.events!
# Inserted paranormal-67 into db.events!
# Inserted sumter-south-carolina-ghost-hunters into db.events!
# Inserted Carolina-Paranormal-Investigate-Society into db.events!
# Inserted Carolina-Paranormal-Research-Society into db.events!
# Inserted Utah-Ghoat-Chronicles into db.events!
# Inserted ParanormalAndTheUnknown into db.events!
# Inserted mysticnirvanaparanormal into db.events!
# Inserted Nevada-MUFON-Chapter into db.events!
# Inserted Boca-Raton-Ghost-Tracking-Meetup into db.events!
# Inserted Miami-International-UFO-Awareness-Group into db.events!
# Inserted ParanormalToledo into db.events!
# Inserted Pahrump-Ghost-Tracking-Meetup into db.events!
# Inserted San-Diego-LEGIONS-OF-LIGHT-UFO-SKYWATCH-COM into db.events!
# Inserted San-Diego-After-Death-Communications-Meetup into db.events!
# Inserted STARGATE-2012-AND-BEYOND-AND-The-SD-UFO-SOCIETY into db.events!
# Inserted Association-of-Paranormal-Study into db.events!
# Inserted Paranormal-Detroit-Meetup into db.events!
# Inserted San-Diego-Soul-Astronauts into db.events!
# Inserted NC-MUFON into db.events!
# Inserted Paranormal-Cleveland into db.events!
# Inserted Akron-Paranormal-Investigations into db.events!
# Inserted ET-Disclosure-Contact-Metro-Detroit into db.events!
# Inserted Psychic-Medium-Melinda-Carver-Events into db.events!
# Inserted meetup-group-moofMEfP into db.events!
# Inserted Alien-And-UFO-Book-Club into db.events!
# Inserted WAPERS into db.events!
# Inserted Whittier-Paranormal-Investigations into db.events!
# Inserted Sasquatch-Believers into db.events!
# Inserted Los-Angeles-Walking-Dead-Horror-Films-Meetup into db.events!
# Inserted CERO-International into db.events!
# Inserted Scary-LA-Escapers-A-subgroup-of-LA-Escaper-s into db.events!
# Inserted Santa-Monica-Paranormal-UFO-Meeting-Group into db.events!
# Inserted Affected-By-The-Mandela-effect into db.events!
# Inserted SpiritualityParanormal101Niagara into db.events!
# Inserted Buffalo-UFO-Meetup into db.events!
# Inserted Alternative-Media-Fans-Toronto-and-Global into db.events!
# Inserted MUFON-Canada-Meetings-and-events into db.events!
# Inserted Boise-Horror-Cult into db.events!
# Inserted Bridgeville-Ghost-Tracking-Meetup into db.events!
# Inserted Middletown-Para-Co-Op into db.events!
# Inserted RealGhostAdventures into db.events!
# Inserted California-Haunts into db.events!
# Inserted Binghamton-Area-Paranormal-Research-Meetup into db.events!
# Inserted proveghosts into db.events!
# Inserted San-Jose-Personal-Paranormal-Experiences-Meetup into db.events!
# Inserted San-Leandro-UFO-Meetup into db.events!
# Inserted bay-area-paranormals into db.events!
# Inserted ca-paranormal-inv-group into db.events!
# Inserted New-York-Flat-Earth-Meetup into db.events!
# Inserted NYC-ENTITY-INVESTIGATIONS into db.events!
# Inserted NEW-YORK-CEMETERY-HIKING-GROUP into db.events!
# Inserted Middleburgh-Knowledge-Sharing-Meetup into db.events!
# Inserted HistoryTimeLinesAndParanormal into db.events!
# Inserted ParanormalPuzzle into db.events!
# Inserted meetup-group-HgoMcraq into db.events!
# Inserted meetup-group-rVnKLaUp into db.events!
# Inserted ghosts-656 into db.events!
# Inserted Eugene-Paranormal-Investigations into db.events!
# Inserted Miracles-Inspiration-Meetup into db.events!
# Inserted Ghosthealers into db.events!
# Inserted RedmondZombies into db.events!
# Inserted Edmonton-Ghost-Tracking-Meetup into db.events!
# Inserted OlyPenESP into db.events!
# Inserted Eyes-of-Kinder-Paranormal-Club-Westport into db.events!
# Inserted The-Coldspotters-FraserValley into db.events!
# Inserted Bigfoot-Encounter into db.events!
# Inserted GhostGuide into db.events!
# Inserted Anchorage-UFO-Research-and-Investigations-Meetup into db.events!
# Inserted Oahu-Paranormal-Adventurers into db.events!
# Inserted Zombie-survival-planners into db.events!
# Inserted Glasgow-Space-Science-Meetup into db.events!
# Inserted The-Unexplained into db.events!
# Inserted uforp_ into db.events!
# Inserted EastMidlands-UFO-Discussion-Meetup into db.events!
# Inserted Ghost-Collectors-Paranormal-group-Meetup into db.events!
# Inserted spooky-writers-and-creatives into db.events!
# Inserted London-cult-horror into db.events!
# Inserted ASSAP-London into db.events!
# Inserted E-T-Phone-Home-A-Meetup-for-Cosmic-Brothers-and-Sisters into db.events!
# Inserted London-UFO-Discussion-Meetup into db.events!
# Inserted Meetup-PSI-PMOA into db.events!
# Inserted Chasseurs-de-Fantomes-Du-Group-Meetup-De-Paris into db.events!
# Inserted Rational-UFO-studies into db.events!
# Inserted The-Lebanese-Ghost-Tracking-Meetup-Group into db.events!
# Inserted Mysterious-world into db.events!
# Inserted Digos-Paranormal-Investigations-Meetup into db.events!
# Inserted Paranormal-Research-Mumbai into db.events!
# Inserted Indian-Paranormal-Team-Pune into db.events!
# Inserted ParanormalsPune into db.events!
# Inserted I-believe-Supernatural into db.events!
# Inserted hidden-stitch into db.events!
# Inserted Bangalore-Paranormal-Enthusiasts-Meetup into db.events!
# Inserted anythinghealing into db.events!
# Inserted London_Cultureseekers into db.events!
# Inserted BarcelonaLanguageExchange into db.events!
# Inserted RaDNorthCounty into db.events!
# Inserted Thumbs-Up-Theatre-Toronto into db.events!
# Inserted NYC-and-NJ-Walks-Explore-Architecture-Art-History-Sculpture into db.events!
# Inserted drawingnewyork into db.events!
# Inserted Inflitrados-en-Barcelona into db.events!
# Inserted London-Life-drawing-Aldgate-and-Shoreditch into db.events!
# Inserted ARTS-COMPANY-actividades-culturales-y-ocio-compartido into db.events!
# Inserted Wien-erleben into db.events!
# Inserted Toronto-Arts-and-Culture into db.events!
# Inserted The-Souls-of-Black-Folk into db.events!
# Inserted Conferencias-sobre-arte-y-Visitas-Guiadas-en-Madrid into db.events!
# Inserted Like-Minded-People-of-Culture-in-London into db.events!
# Inserted Hong-Kong-Sacred-Spaces into db.events!
# Inserted SF-Sketchers into db.events!
# Inserted St-L-Historic-Sites-Meetup into db.events!
# Inserted Hong-Kong-Art-Development into db.events!
# Inserted Life-Drawing-Manchester into db.events!
# Inserted LondonLifeDrawing into db.events!
# Inserted JOZI-walks-culture-and-fun into db.events!
# Inserted greenpointfiguredrawing into db.events!
# Inserted Rockland-Singles-50-plus-Afternoon-Walk-Hiking-Meetup-Group into db.events!
# Inserted Acting-Gymnasium-unique-weekly-acting-workshop into db.events!
# Inserted Newcastle-Film-Theatre-and-Social into db.events!
# Inserted columbia-dsl into db.events!
# Inserted letterpdx into db.events!
# Inserted Arts-Cultural-Events into db.events!
# Inserted Philadelphia-30s-and-40s-Social-Group into db.events!
# Inserted Art-Gallery-Crawl-in-Paris-Vernithon into db.events!
# Inserted New-York-Creative-Socials into db.events!
# Inserted Creative-Introverts-Being-Extroverts-20s-30s into db.events!
# Inserted creativesessions into db.events!
# Inserted Art-Explorers into db.events!
# Inserted Stockholm-Acting-Improv-Meetup into db.events!
# Inserted Art-in-Tech-Atlanta into db.events!
# Inserted BCNComedyClub into db.events!
# Inserted vernithon into db.events!
# Inserted Use-that-Museumkaart into db.events!
# Inserted Culture-Club-Birmingham into db.events!
# Inserted improvise-till-you-make-it into db.events!
# Inserted Chicago-Gallery-Openings-Plus into db.events!
# Inserted palmbeachartists into db.events!
# Inserted WhatisHappeningInCanberra into db.events!
# Inserted Dynamic-Figure-Drawing-in-Brooklyn into db.events!
# Inserted Finding-Female-Friends-Past-Fifty-Boise into db.events!
# Inserted Parques-historicos-de-Madrid-con-encanto-desconocidos into db.events!
# Inserted Acting-for-Beginners-Dublin-Workshop-Meetup into db.events!
# Inserted Art-Gallery-Crawl-in-Brussels-Vernithon-of-Brussels into db.events!
# Inserted nottingham-culture-cafe-sci into db.events!
# Inserted sketching into db.events!
# Inserted Stockholm-Creative-People-Meetup into db.events!
# Inserted FreeLondonEvents into db.events!
# Inserted The-Storytellers-Night into db.events!
# Inserted Amantes-del-Teatro-CDMX into db.events!
# Inserted meetup-group-eGAmCUWN into db.events!
# Inserted The-Amsterdam-Culture-Group into db.events!
# Inserted ChicagoMeetup into db.events!
# Inserted Art-lovers into db.events!
# Inserted New-York-Tech-Creatives into db.events!
# Inserted Classical-Connection into db.events!
# Inserted omahacultureclub into db.events!
# Inserted African-African-American-Art into db.events!
# Inserted art-494 into db.events!
# Inserted Drawing-London-on-Location into db.events!
# Inserted Denver-Art-Societ into db.events!
# Inserted Showtime-fun-time into db.events!
# Inserted Drop-in-Life-Drawing-Painting-in-Central-Tokyo into db.events!
# Inserted Drink-and-Draw-NucleusPortland into db.events!
# Inserted Art-Geeks into db.events!
# Inserted Life-Drawing-With-ELSC into db.events!
# Inserted meetup-group-vHquiJAl into db.events!
# Inserted Planes-diferentes-y-cultura-en-Madrid into db.events!
# Inserted Art-and-alcohol into db.events!
# Inserted Planes-baratos-en-Barcelona into db.events!
# Inserted thatstheticket into db.events!
# Inserted London-Arts-Culture-Group into db.events!
# Inserted Musees-et-expositions into db.events!
# Inserted Singles-exploring-the-history-cuisine-culture-of-New-Haven into db.events!
# Inserted London-Shoal-of-Art-Meetup into db.events!
# Inserted Theatre-GameMelbournesand-Improvisational-Workshop into db.events!
# Inserted chez-Grace-Charleston into db.events!
# Inserted Draw-Club-Bristol into db.events!
# Inserted Paris-Drawing-Meetup into db.events!
# Inserted Creative-Original-Artist-Cartel into db.events!
# Inserted Fairfield-County-It into db.events!
# Inserted lyon-carnets-croquis into db.events!
# Inserted Hammerspace-Community-Workshop-and-Makerspace into db.events!
# Inserted Manchester-Art-Meetup into db.events!
# Inserted life-drawing-montmartre into db.events!
# Inserted Creators-and-thinkers-of-Shanghai into db.events!
# Inserted CulturedMilwaukee into db.events!
# Inserted LA-Architecture-Art-Meetup into db.events!
# Inserted TheActorsPlace into db.events!
# Inserted LifeDrawingBoston into db.events!
# Inserted Teatre-BCN into db.events!
# Inserted Jacksonville-Theater-Lovers into db.events!
# Inserted Midtown-Miami-Social-Art-Fashion-Music into db.events!
# Inserted Drink-and-Draw-Bay into db.events!
# Inserted SF-Improv into db.events!
# Inserted NYC-Cultural-Meetup-museums-sailing-walks-exploring into db.events!
# Inserted Madrileandopormadrid into db.events!
# Inserted NukkadCafe into db.events!
# Inserted drawingindc into db.events!
# Inserted artforward into db.events!
# Inserted Vancouver-Urban-Sketchers into db.events!
# Inserted Random-Fun-Stuff-I-Want-To-Do-On-a-Short-Notice-Club into db.events!
# Inserted NYC-Art-Meetup into db.events!
# Inserted Fresh-Ground-Stories into db.events!
# Inserted Glasgow-Life-Drawing-and-Sketching into db.events!
# Inserted LGBT-Culture-Lovers into db.events!
# Inserted Drink-n-Draw into db.events!
# Inserted Creative-Cafe-Austria into db.events!
# Inserted Cocktails-and-Culture into db.events!
# Inserted Boulder-Experiments-in-Art-and-Technology into db.events!
# Inserted Historic-Cities-Churches-and-Cemeteries into db.events!
# Inserted Imaginative-Illustrators-Of-NYC into db.events!
# Inserted culturevulturesBoston into db.events!
# Inserted Brighton-Creative-Cafe into db.events!
# Inserted The-Drawing-Circle-Valencia into db.events!
# Inserted Meetup-de-Eventos-en-Barcelona into db.events!
# Inserted The-Arts-Meet into db.events!
# Inserted Vienna-Atelier-of-Traditional-Art into db.events!
# Inserted TCS-in-the-moment-improv-program into db.events!
# Inserted BoulderImprov into db.events!
# Inserted victoriaurbansketchers into db.events!
# Inserted meetup-group-StNnHMYk into db.events!
# Inserted creativeCodeBerlin into db.events!
# Inserted Art-Fest-Lovers-Group into db.events!
# Inserted DRAFTart into db.events!
# Inserted Durham-TED-Talks-Meetup into db.events!
# Inserted NY-Comic-Book-Writers-Creators into db.events!
# Inserted Malmo-Improvisatorium into db.events!
# Inserted Theatre-Games-in-the-Park into db.events!
# Inserted Queer-Culture-Vultures into db.events!
# Inserted Artists-Santa-Fe into db.events!
# Inserted Toronto-Improv-Actors-Meetup into db.events!
# Inserted sacBPs into db.events!
# Inserted La-Fisgona into db.events!
# Inserted SketchBomb-Barcelona into db.events!
# Inserted Comedy-Nights-Zurich into db.events!
# Inserted Friends-of-the-Wissahickon into db.events!
# Inserted Business-Skills-for-Creative-Souls into db.events!
# Inserted Ridgmont-Life-Drawing-Meetup into db.events!
# Inserted Become-an-Artist-London into db.events!
# Inserted Interactive-Storytelling-Meetup into db.events!
# Inserted spektrum into db.events!
# Inserted Young-Members-of-the-Art-Gallery-of-NSW into db.events!
# Inserted WorldChessHOF into db.events!
# Inserted MetroDetroitImprov into db.events!
# Inserted Freehand-Sketch-LA into db.events!
# Inserted Creative-Roundtable into db.events!
# Inserted Working-Out-Loud-in-Hannover into db.events!
# Inserted Freehand-Drawing-in-Melbourne into db.events!
# Inserted 2ndVerse into db.events!
# Inserted shakespeare-50 into db.events!
# Inserted Edinburgh-Life-Drawing-Meetup into db.events!
# Inserted Life-Drawing-drop-in-Amsterdam-4bid-gallery-OT301 into db.events!
# Inserted Growth-Mindset-fordern into db.events!
# Inserted Raleigh-Figure-Drawing-Drink-and-Draw into db.events!
# Inserted Santa-Cruz-Visual-Artist-Meetup into db.events!
# Inserted Get-me-off-the-couch into db.events!
# Inserted ActingGym into db.events!
# Inserted Montreal-Sketching-Group into db.events!
# Inserted Topsham_Area_Social_Meetup into db.events!
# Inserted Lovers-Of-Black-Theatre into db.events!
# Inserted Artkhoj into db.events!
# Inserted Doodle-Dudes-TX into db.events!
# Inserted meetup-group-OOWEwfIF into db.events!
# Inserted Raleigh-Durham-Brain-Pickings-Book-Club into db.events!
# Inserted Adventures-in-Art into db.events!
# Inserted WomenofcultureNYC into db.events!
# Inserted Montreal-Art-Centre-Meetup into db.events!
# Inserted Drink-Draw-Ballard into db.events!
# Inserted The-creative-workshop into db.events!
# Inserted Berlin-Portrait-Drawing-Group into db.events!
# Inserted monamilifedrawing into db.events!
# Inserted museum-107 into db.events!
# Inserted Melbourne-Creative-AI-Meetup into db.events!
# Inserted drawpaintstl into db.events!
# Inserted TheArtistsLeague into db.events!
# Inserted Studio117B into db.events!
# Inserted Makeportland into db.events!
# Inserted Cambridge-sketch-group into db.events!
# Inserted atelierwinter into db.events!
# Inserted Community-of-Creative-Minds-in-al-sharqiya into db.events!
# Inserted LA-Play-Reading into db.events!
# Inserted Linden-Street-Figure-Drawing into db.events!
# Inserted Portland-Coffee-Sketch-Club into db.events!
# Inserted Like-minded-peopleinlondon into db.events!
# Inserted Norwich-Creative-Freelancers-Meetup into db.events!
# Inserted Improv-For-Everyone-Munich into db.events!
# Inserted Denver-Art-Food-Enthusiasts into db.events!
# Inserted TC-Drawing into db.events!
# Inserted South-Bay-Sketchers into db.events!
# Inserted WipComics into db.events!
# Inserted Improvisationet-rencontres into db.events!
# Inserted agenda-gratisobarato-barcelona into db.events!
# Inserted TOKYO-ART-LOVERS-CREATORS into db.events!
# Inserted GroupArtCircle into db.events!
# Inserted comedy-and-craft-brews into db.events!
# Inserted Open-Mic-Poetry-Night-in-the-Gallery-Meetup into db.events!
# Inserted Drink-and-Draw-OC into db.events!
# Inserted Events-at-Joshua-Creek-Arts into db.events!
# Inserted Shoestring-Studio into db.events!
# Inserted Drink-and-Draw-at-Alberta-Street-Gallery into db.events!
# Inserted Tacoma-Improv-Play-Games-Meetup into db.events!
# Inserted Drawing-Club-Edinburgh into db.events!
# Inserted Art-Galleries-And-Exhibitions-In-Bristol-And-Bath into db.events!
# Inserted Life-Drawing-Meetup into db.events!
# Inserted il-mare-visto-dal-mare into db.events!
# Inserted Bayside-Culture-Vultures-50 into db.events!
# Inserted Learn-Improvisation-in-Kansas-City into db.events!
# Inserted artgalleriesinLA into db.events!
# Inserted District-Creatives into db.events!
# Inserted Art-Code-Collective into db.events!
# Inserted SacDils into db.events!
# Inserted BrooklynDrawingMeetup into db.events!
# Inserted Newcastle-Upon-Tyne-Creativity-Meetup into db.events!
# Inserted Teatro-Musica-y-Comedia-Low-Cost into db.events!
# Inserted Jeux-dimpro-a-Paris into db.events!
# Inserted Orlando-Out-Tonight-Theatre-Meetup into db.events!
# Inserted utahtheaterlovers into db.events!
# Inserted Arlington-painting-sessions into db.events!
# Inserted Thursday-Night-Gallery-Hop into db.events!
# Inserted Bristol-Movie-Theatre-Fans into db.events!
# Inserted St-Albans-Life-Drawing-Meetup into db.events!
# Inserted Soho-Life-Drawing-Shorts into db.events!
# Inserted LondonDrawing into db.events!
# Inserted LDNArtLovers into db.events!
# Inserted Amsterdam-Treehouse-Open-Mic-Books-Poetry-and-Music into db.events!
# Inserted Painting-and-Drawing-Workshops-for-beginners into db.events!
# Inserted Inquiet-s-por-Madrid into db.events!
# Inserted Improvisation-theatre-Improv into db.events!
# Inserted Wiesbaden-Kunst into db.events!
# Inserted DesignJapan into db.events!
# Inserted Sydney-Improv-Jam into db.events!
# Inserted Austin-Improv-Connection into db.events!
# Inserted hamemg into db.events!
# Inserted Triangle-Sketch-Crawl into db.events!
# Inserted Baltimore-Art-Meetup into db.events!
# Inserted The-Dublin-Theatre-Group into db.events!
# Inserted Pro-Brexit-Creative-Network into db.events!
# Inserted Drink-and-Draw into db.events!
# Inserted ArtsQuake into db.events!
# Inserted Brussels-Improv-Unlimited into db.events!
# Inserted Fun-Loving-Intellectual-Cultured-Singles-Ages-46plus into db.events!
# Inserted Columbus-Art-Meetup into db.events!
# Inserted Painting-with-Mom into db.events!
# Inserted Toronto-Doodlers into db.events!
# Inserted Creatively-Spirited into db.events!
# Inserted Art-Journal-Sonoma-County-Unfold-Studio into db.events!
# Inserted Puget-Sound-Theatre-Scene into db.events!
# Inserted French-Culture-Edmonton-Meetup-Group into db.events!
# Inserted The-Sketchbookers into db.events!
# Inserted Candid-Arts-Life-Drawing-Meetup into db.events!
# Inserted Improv-Rotterdam into db.events!
# Inserted Amsterdam-Culture-Club into db.events!
# Inserted Baden-Conversation-Cafe-Meetup into db.events!
# Inserted Wien-English-Improv into db.events!
# Inserted Creative-Code-Budapest into db.events!
# Inserted Soul-Art-Center-Dxb-Enrich-ur-Soul-with-Art-Dance-Workshops into db.events!
# Inserted Alhambra-Sketching-Meetup into db.events!
# Inserted Night-Life-With-Singles into db.events!
# Inserted shakespeare-41 into db.events!
# Inserted comedy-161 into db.events!
# Inserted cambridge-improv-incubator into db.events!
# Inserted meetup-group-NurseryTheatre into db.events!
# Inserted Oslo-Fine-Arts-Meetup into db.events!
# Inserted the-open-draw into db.events!
# Inserted Masters-Of-Mindset into db.events!
# Inserted Artist-stop-being-poor into db.events!
# Inserted Paper_pencil_caffeine into db.events!
# Inserted Made-to-Create into db.events!
# Inserted Dallas-Sketchers into db.events!
# Inserted Mindful-Improv into db.events!
# Inserted Creative-Growth-SoCal into db.events!
# Inserted Philly-Loves-Theatre-Broadway-and-other-Shenanigans into db.events!
# Inserted Tea-Draw into db.events!
# Inserted Storytellers-of-New-York into db.events!
# Inserted theaterbuffs into db.events!
# Inserted Stevenage-Life-drawing into db.events!
# Inserted meetup-group-QbIcDzkS into db.events!
# Inserted Meetup-Adultes-HP-Zebres-Geneve into db.events!
# Inserted TennesseeVoiceOverExchange into db.events!
# Inserted DenverArtistsMeetup into db.events!
# Inserted Art-Verve into db.events!
# Inserted louisvillecomedy into db.events!
# Inserted Columbia-Improv-Practice-Group into db.events!
# Inserted BrokenAnchorPoetry into db.events!
# Inserted SanDiegoLifeDrawing into db.events!
# Inserted discoverLAmeetup into db.events!
# Inserted Improv-on-the-Westside into db.events!
# Inserted New-York-Pianist-Club into db.events!
# Inserted Art-Meetup-Group-of-Victoria-BC into db.events!
# Inserted Expats-International-Friends-London into db.events!
# Inserted Improvisation-Fun into db.events!
# Inserted Acting-Studio-London into db.events!
# Inserted Camberwell-Life-Drawing into db.events!
# Inserted Canterbury-Life-Drawing-Meetup into db.events!
# Inserted The-Amsterdam-Urban-Sketchers into db.events!
# Inserted Art-Technology-Society-Eindhoven into db.events!
# Inserted Descubrir-Girona-y-la-Costa-Brava into db.events!
# Inserted HongKongStories into db.events!
# Inserted Architecture-events-in-Melbourne into db.events!
# Inserted BKK-Sketchers into db.events!
# Inserted happinessartstudio into db.events!
# Inserted Bangalore-Art-Crafts-Meetup into db.events!
# Inserted UrbanSketchers_Austin into db.events!
# Inserted Houston-Improv-and-Stand-Up-Comedy-Troupe into db.events!
# Inserted TheatreGoers into db.events!
# Inserted Figure-Drawing-Chicago into db.events!
# Inserted Las-Vegas-Drawing into db.events!
# Inserted Orange-County-Art-and-Culture into db.events!
# Inserted DC-Drink-Draw into db.events!
# Inserted Museums-Merriment-and-Munchies into db.events!
# Inserted Burlingame-Plein-Air-Painters into db.events!
# Inserted drawingbrooklyn into db.events!
# Inserted Portland-Coffee-Art-and-Music-Meetup into db.events!
# Inserted Sketchy-Breakfasts into db.events!
# Inserted Nottingham-Improv-Comedy-Experience into db.events!
# Inserted Tech-Art-Lisboa into db.events!
# Inserted London-Art-Drawing-Meetup-Group into db.events!
# Inserted madimprov into db.events!
# Inserted Pincelea-Barcelona-pintar into db.events!
# Inserted Berlin-independent-film-community into db.events!
# Inserted Milano-Art-Painting-and-Drawing-Meetup into db.events!
# Inserted Kimono-Life-Drawing-in-Tokyo into db.events!
# Inserted batonrougefilm into db.events!
# Inserted Santa-Fe-Drink-and-Draw-20s-and-30s into db.events!
# Inserted North-Phoenix-Figure-Drawing-and-Open-Studios into db.events!
# Inserted North-Charleston-Art-Meetup into db.events!
# Inserted A-Paris-Salon into db.events!
# Inserted CJ-51plus into db.events!
# Inserted crewcrewRWC into db.events!
# Inserted sfArts into db.events!
# Inserted CUNY-Arts into db.events!
# Inserted nycshowtime into db.events!
# Inserted Rockland-Bergen-Dinner-Movies-and-Broadway into db.events!
# Inserted Calgary-Artists-Plein-Aire-Meetup into db.events!
# Inserted Edmonton-Doodlebugs into db.events!
# Inserted Dorset-Friendship-Group into db.events!
# Inserted The-Sketchbookers-Oxford into db.events!
# Inserted Arts-Culture-Alternate into db.events!
# Inserted Improv-Den-Haag into db.events!
# Inserted FREE-Film-And-Theatre-University-Paris-France into db.events!
# Inserted art-nights-out into db.events!
# Inserted Teatro-Italiano-Barcellona into db.events!
# Inserted Do-Arty-Stuff into db.events!
# Inserted ArtExplore-Wellington into db.events!
# Inserted Life-Drawing-Sukhumvit-soi-33-1 into db.events!
# Inserted Oklahoma-City-Art-Meetup into db.events!
# Inserted Female-Artists-of-Atlanta into db.events!
# Inserted Naperville-Arts-Crafts-Meetup into db.events!
# Inserted Milwaukee-InDesign-User-Group into db.events!
# Inserted Cura-Studios-Open-Figure-Session into db.events!
# Inserted North-Jersey-Live-Comedy-Fans into db.events!
# Inserted unionsquare into db.events!
# Inserted Redding-Theater-Goers-Group into db.events!
# Inserted RnG-Calgary-Music into db.events!
# Inserted Arts-Festival-Volunteering into db.events!
# Inserted Leeds-Play-Readers into db.events!
# Inserted Guildford-Figure-Drawing-Meetup into db.events!
# Inserted Great-WALK-of-Art into db.events!
# Inserted soholifedrawing into db.events!
# Inserted BCN-Cultural-Events into db.events!
# Inserted Berlin-Sketch-Together into db.events!
# Inserted The-Fine-Art-Network into db.events!
# Inserted Sketchgroup_Vienna into db.events!
# Inserted Kyoto-Art-Meetup into db.events!
# Inserted Abu-Dhabi-Drama-Group into db.events!
# Inserted Canberra-Stories-behind-the-Art-Group into db.events!
# Inserted Plein-Air-Austin-Painting-Meetup into db.events!
# Inserted Weekly-Dallas-Improv-Jam into db.events!
# Inserted New-Orleans-Improv-Comedy into db.events!
# Inserted Pop-Up-Art-Parties into db.events!
# Inserted Open-Session into db.events!
# Inserted orlandoartists into db.events!
# Inserted Pens-Eat-Pencils-Columbus into db.events!
# Inserted going-IMPROV into db.events!
# Inserted Miami-Figure-Drawing-Saturday-Morning-Group into db.events!
# Inserted Ann-Arbor-Sketch into db.events!
# Inserted SanDiegoExpressiveArts into db.events!
# Inserted Sip-and-Sketch into db.events!
# Inserted Toronto-Urban-Sketchers into db.events!
# Inserted South-Bay-Art into db.events!
# Inserted Code-in-Color into db.events!
# Inserted Alameda-Artists into db.events!
# Inserted Oakland-Improv-Comedy-Meetup into db.events!
# Inserted High-Low-Art-Space into db.events!
# Inserted Concept-Art-Dublin into db.events!
# Inserted Dublin-Acting-Workshops into db.events!
# Inserted manchester-life-drawing into db.events!
# Inserted meetup-group-fhRRUKhO into db.events!
# Inserted Crouch-End-Figure-Life-Drawing into db.events!
# Inserted London-Artists-Way-Meetup into db.events!
# Inserted Write-or-Draw-Drink-Chat into db.events!
# Inserted arte-e-programacao into db.events!
# Inserted Madrid-Arte into db.events!
# Inserted Hamburg-Drawing-Meetup into db.events!
# Inserted Stockholm-Architecture-Interior-Design-Meetup into db.events!
# Inserted Nurnberg-Liberating-Structures-User-Group into db.events!
# Inserted Life_Drawing_Vienna into db.events!
# Inserted Theatre-Lovers-And-Gay-Social-Group-Sydney into db.events!
# Inserted Walking-History into db.events!
# Inserted The-Arts-Theater-Performance-Meetup-Group into db.events!
# Inserted SLC-Art-Events into db.events!
# Inserted Indie-Creatives-San-Diego into db.events!
# Inserted Late-Night-Draw into db.events!
# Inserted Haddonfield-Art-Meetup into db.events!
# Inserted Creativity-Club-Mid-Peninsula into db.events!
# Inserted StorySlam-Oakland into db.events!
# Inserted the-group-with-no-name into db.events!
# Inserted newburghnewyork into db.events!
# Inserted Beacon-BookClub into db.events!
# Inserted Bristol-Life-Drawing into db.events!
# Inserted Botanical-illustration-in-Hackney into db.events!
# Inserted Brighton-Sketching-Group into db.events!
# Inserted Den-Haag-Creative-Minds-Meetup-and-Collaboration into db.events!
# Inserted apuntesdelnatural into db.events!
# Inserted Improlib-Improvisez-quand-vous-voulez into db.events!
# Inserted impro-Americaine-a-Paris-bilingue into db.events!
# Inserted Drinks-Drawings-Bebidas-y-Dibujos into db.events!
# Inserted Meetup-Sorties-et-detente-Lyon into db.events!
# Inserted Blender-3D-Berlin into db.events!
# Inserted Art-Workshops-Zurich into db.events!
# Inserted Femaile-Friends-over-Fifty into db.events!
# Inserted Meetup-Recitazione-e-tempo-libero-Milano into db.events!
# Inserted Felnőtt-Szinjatszo into db.events!
# Inserted meetup-group-cwbyqaHo into db.events!
# Inserted Osaka-Artists-and-Designers-Meetup into db.events!
# Inserted Hong-Kong-Art-Meetup into db.events!
# Inserted Squishface-Comic-Studio-Meetup into db.events!
# Inserted Weirdlings-Gone-Wild-Aged-20s-30s into db.events!
# Inserted Drawing-and-Sketching into db.events!
# Inserted NOLA-Women-Living-Wild-and-Precious into db.events!
# Inserted Scottsdale-Live-Community-Theater-Meetup into db.events!
# Inserted Essence-of-the-Soul into db.events!
# Inserted Miltown-Game-Developers into db.events!
# Inserted Watch-Party into db.events!
# Inserted thedACenterfortheArts into db.events!
# Inserted Creative-Locals-Sketch-Social into db.events!
# Inserted BrandLibrary into db.events!
# Inserted Improv-Ventura into db.events!
# Inserted Artistic-Artifacts-Alexandria-Artists-Meetup into db.events!
# Inserted DCImprovTheater into db.events!
# Inserted Chrysler-Museum-of-Art-Enthusiasts into db.events!
# Inserted Mississauga-Improv-Meetup-Self-Improv-ment into db.events!
# Inserted Creatives-helping-Creatives into db.events!
# Inserted New-York-Asian-Creative-Design-Club into db.events!
# Inserted Portrait-Sketch-Practice-Group into db.events!
# Inserted ArtMontreal into db.events!
# Inserted BostonArt into db.events!
# Inserted Arty-Creatives-Edinburgh-ACE into db.events!
# Inserted The-Oxford-Art-Group into db.events!
# Inserted Kingston-Arts-Networking-Evening into db.events!
# Inserted London-Artists into db.events!
# Inserted Sketchy-Bitches into db.events!
# Inserted acting-classes-in-London into db.events!
# Inserted Amsterdam-printmakin-bookbinding-meetup into db.events!
# Inserted Planes-LGTB-en-Madrid into db.events!
# Inserted meetup-group-fXfNRqVx into db.events!
# Inserted Sitios-curiosos-en-Madrid-Arte-e-historia into db.events!
# Inserted Rutas-Teatrales-Descubramos-las-Artes-Escenicas-Madrilenas into db.events!
# Inserted PJV-Acting into db.events!
# Inserted Art-Mindfulness into db.events!
# Inserted Watercolor-International-BAC into db.events!
# Inserted Lovetheatre-Milan into db.events!
# Inserted lgbt-friends-in-Vienna-Art-Music-Sports-Theatre into db.events!
# Inserted lifedrawingtokyo into db.events!
# Inserted letsarttaipei into db.events!
# Inserted Watercolor-Painting-Workshop into db.events!
# Inserted COME-DRAW-WITH-WING-URBAN-EXPLORER into db.events!
# Inserted people-drawing-people into db.events!
# Inserted Creative-Fluid-Art-Club into db.events!
# Inserted Academy-of-Architecture into db.events!
# Inserted Bangkok-Pottery-Club into db.events!
# Inserted painting-for-pleasure into db.events!
# Inserted Soul-Stories into db.events!
# Inserted Community-Fiber-Craft-Night-at-ReCreative-Denver into db.events!
# Inserted Atlanta-Illustrators-Makers-Meetup into db.events!
# Inserted OurMovieClub into db.events!
# Inserted Cincinnati-Creative-Society into db.events!
# Inserted Unorthodox-Studios into db.events!
# Inserted SoCalTangleClub into db.events!
# Inserted Longbeachsketchingmeetup into db.events!
# Inserted Pasadena-Hikers-and-Foodies into db.events!
# Inserted Los-Angeles-Long-form-Improv-practice-and-performance-Group into db.events!
# Inserted Camera into db.events!
# Inserted Improv-Comedy-Meetup-Group into db.events!
# Inserted Long-Island-50-Womens-Theater-Group into db.events!
# Inserted Open-Mic-Night-in-Norwalk-Connecticut into db.events!
# Inserted historyphiles into db.events!
# Inserted Drink-Draw-Capitol-Hill into db.events!
# Inserted Seattle-Social-Tea into db.events!
# Inserted North-Somerset-Beginners-Modern-Calligraphy-Meetup into db.events!
# Inserted LGBTQ-Coffee-Catch-Up into db.events!
# Inserted leicestershire-culture-and-good-intentions-club into db.events!
# Inserted Oxford-Illustrators into db.events!
# Inserted Acting-Classes-for-Adults into db.events!
# Inserted East-London-Art-Wellbeing into db.events!
# Inserted Bilingual-Beginners-Theatre-Workshop into db.events!
# Inserted gbgsketch into db.events!
# Inserted Berlin-Artistically-Creative-Souls-Meetup into db.events!
# Inserted Art-Explorers-Zurich into db.events!
# Inserted Munich-English-Improv-Meetup into db.events!
# Inserted Auckland-Art-and-Chill into db.events!
# Inserted ArtExplore into db.events!
# Inserted Delhi-Ncr-के-Creatives-️ into db.events!
# Inserted Queers-into-Art-Sydney into db.events!
# Inserted Drawn-Together-Sydney-life-drawing-group into db.events!
# Inserted Austin-Arts-Collective into db.events!
# Inserted Alliance-Francaise-de-Denver into db.events!
# Inserted Juspaintandchill into db.events!
# Inserted SomewhereAlongTheWay into db.events!
# Inserted UFotArts into db.events!
# Inserted Chicago-Culture-and-Arts-Club into db.events!
# Inserted The-Artists-Way-Savannah-Meetup into db.events!
# Inserted Delray-Beach-Improv-Meetup into db.events!
# Inserted San-Diego-Adult-Coloring-Meetup into db.events!
# Inserted Catalyst-art into db.events!
# Inserted The-Modern-Actors-Workshop-Los-Angeles into db.events!
# Inserted NeuroTechLA into db.events!
# Inserted Woodland-Hills-Women-Friendship-Meetup into db.events!
# Inserted NOVA-Scribes into db.events!
# Inserted Young-DC-Day-Explorers into db.events!
# Inserted San-Jose-Acting-and-Improv-Games into db.events!
# Inserted SF-Art-Modeling-Trade into db.events!
# Inserted NewLife-Performance-Acting-Workshop-20-Cash-Only into db.events!
# Inserted Draw-Your-Line into db.events!
# Inserted Storytelling-Karaoke-Club into db.events!
# Inserted Art-for-Connection into db.events!
# Inserted Manchester-Creative-Writing-Corner into db.events!
# Inserted Cardiff-Life-Model-and-Artists-Meetup into db.events!
# Inserted Cambridge-mid-80s-mid-90s into db.events!
# Inserted thejollysketcher into db.events!
# Inserted Best-Authentic-Walking-Tours-in-London into db.events!
# Inserted meetup-group-itgwSTcR into db.events!
# Inserted theatregym into db.events!
# Inserted Move-Your-Dreams into db.events!
# Inserted Theatre-dimprovisation-a-la-carte into db.events!
# Inserted Rotterdam-Sketching-Meetup into db.events!
# Inserted Empatiko-Open-play-theater-dialogue-and-co-creation into db.events!
# Inserted Amsterdam-Artist-Ecosystem-Meetup into db.events!
# Inserted Propuestas-culturales-Iverem-viajes-cursos-visitas into db.events!
# Inserted NATURE-ART-MUSIC-mayores-40-years into db.events!
# Inserted LAtelier-Theatre-Developper-ses-talents-de-comedien into db.events!
# Inserted La-Desimpro-J-aime-parler-en-public into db.events!
# Inserted Evenements-artistiques into db.events!
# Inserted Improv-Theatre-in-Bonn-English into db.events!
# Inserted Lund-Malmo-Theatre-Meetup into db.events!
# Inserted Urban-Sketchers-Frankfurt-am-Main-Skizzen-kritzeln into db.events!
# Inserted Act-Right-Now-Barcelona into db.events!
# Inserted Art-Gallery-Crawl-in-Barcelona into db.events!
# Inserted An-unforgettable-artistic-night-Barcelona into db.events!
# Inserted Montpellier-Creative into db.events!
# Inserted Lettering-Calligraphy into db.events!
# Inserted DesignCluj into db.events!
# Inserted Just-Meet into db.events!
# Inserted Northcote-Life-Drawing into db.events!
# Inserted DFWDAMP into db.events!
# Inserted Mid-Southern-Watercolorists-Meetup into db.events!
# Inserted ART-CONNECTION into db.events!
# Inserted South-Denver-Artists-Musicians-Showcase into db.events!
# Inserted Lakewood-Arts into db.events!
# Inserted Showcase-of-the-Mondays-And-Open-Mic-Comedy-show into db.events!
# Inserted Meet-Up-at-the-Evansville-Museum into db.events!
# Inserted BoulderArtAssociation into db.events!
# Inserted Atlanta-Figure-Drawing-Sketch-Group into db.events!
# Inserted artoutloudatl into db.events!
# Inserted SW-Art-Glass-Meetup into db.events!
# Inserted Naperville-Writers-Working-Group into db.events!
# Inserted Chicago-Gay-Drink-and-Draw into db.events!
# Inserted meetup-group-sBDqlZuA into db.events!
# Inserted Art-Out-of-School into db.events!
# Inserted westsidemarkers into db.events!
# Inserted ArtisticWomenInspiringArtisticWomenWH into db.events!
# Inserted Improv-practice-in-NOVA into db.events!
# Inserted Working-from-the-Figure-Capitol-Hill-Arts-Workshop into db.events!
# Inserted Digital-Cultural-Heritage-DC into db.events!
# Inserted Root-Studio into db.events!
# Inserted torontoartistsway into db.events!
# Inserted Storytelling-Toronto into db.events!
# Inserted Music-Sing-Alongs into db.events!
# Inserted Plein-Air-Painters-of-Idaho into db.events!
# Inserted Davisfigure into db.events!
# Inserted San-Lorenzo-Night-Photography-Meetup into db.events!
# Inserted San-Francisco-Modern-Calligraphy into db.events!
# Inserted New-York-Artistic-Meetup into db.events!
# Inserted Astoria-Drink-N-Draw into db.events!
# Inserted Somerville-Meditation-Meetup-Art-Workshops-4GoodVibes into db.events!
# Inserted Design-Museum-Portland into db.events!
# Inserted Life-Drawing-at-the-Elisabeth-Jones-Art-Center into db.events!
# Inserted Dover-Creativity-Corner into db.events!
# Inserted Vancouver-Visual-Artists into db.events!
# Inserted City-Life-Drawing into db.events!
# Inserted City-of-Edinburgh-Cultural-Events-Food-for-Thought into db.events!
# Inserted improvise into db.events!
# Inserted Catford-Life-Drawing into db.events!
# Inserted Oslo-Collaboration-between-Creative-Minds-Meetup into db.events!
# Inserted dance-musique-theatre-cine-debat into db.events!
# Inserted Worlds-Meetup into db.events!
# Inserted ARTivities-bcn into db.events!
# Inserted eng-walking-tours-Barcelona into db.events!
# Inserted Barcelona-Improv-Group into db.events!
# Inserted Character-Design-Budapest into db.events!
# Inserted Hong-Kong-Visual-Arts into db.events!
# Inserted Rising-Litera-Indore into db.events!
# Inserted Melbourne-Social-Art-Meetup-in-the-Docklands into db.events!
# Inserted classepetit into db.events!
# Inserted meetup-group-qwDLNYKz into db.events!
# Inserted Deegeez-Creatives into db.events!
# Inserted Bangalore-NewAge-Artists-Meetup into db.events!
# Inserted Social-Night-Owls into db.events!
# Inserted Dallas-Cartoonists-Meetup into db.events!
# Inserted encore into db.events!
# Inserted STL-Childfree-Women-30s-40s-Meetup into db.events!
# Inserted Manitou-Art-Center-MAC-shop into db.events!
# Inserted History-The-Arts into db.events!
# Inserted Denver-Arts-Entertainment-Meetup into db.events!
# Inserted workinprogress into db.events!
# Inserted Tucson-Adobe-User-Group into db.events!
# Inserted Monroe-Walton-County-Center-For-The-Arts into db.events!
# Inserted naperville-figure-drawing into db.events!
# Inserted FAVO-First-Fridays into db.events!
# Inserted MkeAdultColoring into db.events!
# Inserted UNLEASHCREATIVITY into db.events!
# Inserted Black-Girl-in-the-Arts into db.events!
# Inserted Akron-Art-Meetup into db.events!
# Inserted Life-Drawing-Muze into db.events!
# Inserted CartoonArtsCenter into db.events!
# Inserted Hollywood-Playhouse-acting-studio into db.events!
# Inserted ImprovMasters into db.events!
# Inserted The-Inclusive-Collective-for-All-Creative-Arts into db.events!
# Inserted Washington-Musicals-Meetup into db.events!
# Inserted Reno-Improv-Meetup into db.events!
# Inserted nsaa360 into db.events!
# Inserted DIY-Theatre into db.events!
# Inserted oaktownimprov into db.events!
# Inserted EastBaySketchers into db.events!
# Inserted San-Rafael-Figure-Drawing-Salon into db.events!
# Inserted Jersey-City-Art-Talk into db.events!
# Inserted The-Valley-Improv into db.events!
# Inserted Creative-Drawing-Painting into db.events!
# Inserted Boston-Figurative-Art-Center into db.events!
# Inserted Introduction-to-Art-Journaling into db.events!
# Inserted Events-at-Push-Pull-Ballard into db.events!
# Inserted badego into db.events!
# Inserted Drawing-Club-Cheltenham into db.events!
# Inserted Primrose-Hill-Life-Drawing-London into db.events!
# Inserted Improvable into db.events!
# Inserted Journeys-into-Photography-Meetup into db.events!
# Inserted ArtModelCollective into db.events!
# Inserted English-Speaking-Sketchbook-Group-ESSG into db.events!
# Inserted Meetup-de-Coworking-en-Sevilla into db.events!
# Inserted Dessin-de-Nu-Paris into db.events!
# Inserted Brussels-Art-Meetup into db.events!
# Inserted Exhibits-museums-and-art-galleries into db.events!
# Inserted AmigosBarcelona into db.events!
# Inserted Arts-Crafts-Barcelona into db.events!
# Inserted Todo-Teatro-en-Barcelona into db.events!
# Inserted ART-CLUB-BARCELONA into db.events!
# Inserted StoryFusion into db.events!
# Inserted improv-theater-berlin into db.events!
# Inserted Network-for-Artists-Creatives-and-Freelancers into db.events!
# Inserted Lets-Enjoy-Japanese-Culture into db.events!
# Inserted kultur-sanat-hayat into db.events!
# Inserted Wellington-Art-Meetup into db.events!
# Inserted Alliance-Francaise-AD-French-Language-and-Cultural-events into db.events!
# Inserted Canberra-Womens-Art-Therapy-Group into db.events!
# Inserted sketchartist into db.events!
# Inserted Explore-Memphis-and-the-MidSouth into db.events!
# Inserted Artisan-Santa-Fe-Events-More into db.events!
# Inserted Make-Art-Get-Coached into db.events!
# Inserted meetup-group-FwyeYJhW into db.events!
# Inserted DrinkNDrawNashville into db.events!
# Inserted DenverTheater into db.events!
# Inserted Arizonaindiefilm into db.events!
# Inserted Henderson-City-Lights-Art-Gallery-Meetup into db.events!
# Inserted Coral-Springs-Painting-Group into db.events!
# Inserted ScreamingArmadilloIMPROVcomedy-Broward into db.events!
# Inserted San-Francisco-Drawing-Meetup into db.events!
# Inserted DesertMoonVST into db.events!
# Inserted This-Is-Not-a-Book-San-Club-Art-History-Book-Group into db.events!
# Inserted painter-86 into db.events!
# Inserted San-Diego-Drink-Draw into db.events!
# Inserted Orange-County-Voice-Acting-Meetup into db.events!
# Inserted Camarillo-Artists into db.events!
# Inserted Malvern-Visual-Art-Journaling-Meetup into db.events!
# Inserted Lehigh-Valley-Letters into db.events!
# Inserted Drawing-for-Fun-Workshops into db.events!
# ...
# Inserted Arty-Hour into db.events!
# Inserted Creative-Pinellas-Meet-Up into db.events!
# Inserted Incredible-Me-Institute-Inc into db.events!
# Inserted ClearwaterBeginner-oil-and-acrylic-Painting-workshops-Meetup into db.events!
# Inserted Hudson-Cultural-Activities-Meetup into db.events!
# Inserted Art-Clearwater into db.events!
# Inserted Largo-ART into db.events!
# Inserted Greenbriar-Clubhouse-Beginner-Oil-Painting-Class into db.events!
# Inserted Mason-City-Musicians-Meetup into db.events!
# Inserted Canvas-In-Lights-fairy-Oracle-Workshop into db.events!
# Inserted Bliss-Becomes-You-Discovery-Center into db.events!
# Inserted RougueProductions into db.events!
# Inserted Doodle-Dudes-IN into db.events!
# Inserted Art-Lessons-and-Art-Fun-WNC into db.events!
# Inserted pre-TV-Comedy into db.events!
# Inserted Plein-Air-Painting-Workshops-Tampa-Bay into db.events!
# Inserted Diversity-Dinner-Group-Dining-Out into db.events!
# Inserted Tampa-Comedy-Meetup-Group into db.events!
# Inserted Morocco-Creativity-Meetup into db.events!
# Inserted TBFAD1 into db.events!
# Inserted Spanish-Lyric-Theatre into db.events!
# Inserted meetup-group-DCgJYhrS into db.events!
# Inserted Museums-and-Galleries into db.events!
# Inserted New-Tampa-Theatre into db.events!
# Inserted Tampa-Bay-River-Cruise-Lovers-Newbies into db.events!
# Inserted naturefantasies into db.events!
# Inserted Gulf-Coast-History-Lovers into db.events!
# Inserted pigments into db.events!
# Inserted PaintAndCheers into db.events!
# Inserted Southeastern-Voice-Actors-Network into db.events!
# Inserted Learn-to-Paint-Like-the-Old-Masters into db.events!
# Inserted T-s-Cocktail-and-Convo-s-Sip-n-Talk into db.events!
# Inserted Artist-Support-Group-of-North-East-Florida into db.events!
# Inserted Quirky-Characters-of-Jax into db.events!
# Inserted Thought-provoking-Social-engaging-theater-together into db.events!
# Inserted Improv-for-the-Irreverent into db.events!
# Inserted Asheville-20s-30s-Freespirits-Social-Party-Hangin-Club into db.events!
# Inserted Art-Painting-Classes into db.events!
# Inserted Step-by-Step-Painting-Social into db.events!
# Inserted Ladies-Who-Love-Live-Theater into db.events!
# Inserted Art-With-Your-Wine into db.events!
# Inserted Wheaton-Cultural-Arts-Meetup into db.events!
# Inserted Expressive-Arts-Open-Studio into db.events!
# Inserted central-florida-creatives into db.events!
# Inserted WALFChicago into db.events!
# Inserted The-Artists-Way-Meetup-Group-Cincinnati into db.events!
# Inserted Collective-Creations-at-Chapeau-Couture into db.events!
# Inserted Greater-Cincy-Voice-Actors into db.events!
# Inserted Create-a-Painting-in-TWO-Hours into db.events!
# Inserted Elgin-Live-Figure-Drawing into db.events!
# Inserted creativecircle-30 into db.events!
# Inserted Florida-Voice-Acting-Network-and-Education into db.events!
# Inserted Nicosentino-aol-com into db.events!
# Inserted DesignThinking-Cincy into db.events!
# Inserted Berwyn-Art-Meetup into db.events!
# Inserted Art-Therapy-Creativity-Group into db.events!
# Inserted Modern-Masters-Brush-and-Glass into db.events!
# Inserted ArtsTrep into db.events!
# Inserted The-Alexander-Art-Collective-Poetry-Potluck into db.events!
# Inserted Next-Gen-Art-Collecting into db.events!
# Inserted successstories into db.events!
# Inserted Korks-Kolors-at-Luxe-B-Studio into db.events!
# Inserted Essex-Studios-Arts-Community into db.events!
# Inserted Stand-Deliver-Performing-Arts-Improv-Meetup-Group into db.events!
# Inserted Chicago-Alliance-of-Visual-Artists-Meetup into db.events!
# Inserted Life-Drawing-at-the-Old-Courthouse-Arts-Center into db.events!
# Inserted Paupers-Art-Guild-Live-Model-Drop-in-drawing-sessions into db.events!
# Inserted Playtime-for-Creative-Humans into db.events!
# Inserted Chicago-Sketching-for-UX-Design-and-Innovation into db.events!
# Inserted Experiential-Figure-Drawing-at-the-Flat-Iron-Art-Building into db.events!
# Inserted Chicago-Acting-Meetup into db.events!
# Inserted Weekly-Wicker-Park-Comdey-Comdey-writing-improv-meet-up into db.events!
# Inserted rootedcenter into db.events!
# Inserted Sonny-Brightlys-Improv-Comedy-Workshop into db.events!
# Inserted TheDevotedType into db.events!
# Inserted Chicago-Women-in-Architecture into db.events!
# Inserted The-New-New-Mixed-Media-Mondays-at-Collaboraction into db.events!
# Inserted Chicago-Museum-Exploration-Meetup into db.events!
# Inserted Chicago-Day-Players into db.events!
# Inserted Paint-Furniture-And-Sip-Advanced-Furniture-Design into db.events!
# Inserted Chicago-Painting-Class-Paint-Party-Painting-Event-Meetup into db.events!
# Inserted Social-Justice-Theatre-with-Collaboraction into db.events!
# Inserted Chicago-Art-Times into db.events!
# Inserted Shakespeare-Lovers-Meetup-Group into db.events!
# Inserted ZentangleWithFriends into db.events!
# Inserted chicago-museum into db.events!
# Inserted chicago-comedy-theater into db.events!
# Inserted Chicago-Design-Workshops into db.events!
# Inserted artistsway-173 into db.events!
# Inserted Artexchange-Mexico into db.events!
# Inserted Chicago-Improv-Practice-Group into db.events!
# Inserted Chicago-Theater-Meetup into db.events!
# Inserted Chesterton-Valparaiso-20s-30s-Artists-Meetup into db.events!
# Inserted ImprovFOMO into db.events!
# Inserted Friday-night-open-art into db.events!
# Inserted Sip-and-Paint-Nites-at-90-Miles-Cuban-Cafe into db.events!
# Inserted Middletown-Artists-Meetup into db.events!
# Inserted Orlando-Art-Meetup into db.events!
# Inserted Sketchbomb-Savannah into db.events!
# Inserted ExpressionistsCreativeCounseling into db.events!
# Inserted Artist-at-Heart into db.events!
# Inserted Arts-After-Hours-Orlando-Social-Networking into db.events!
# Inserted Architects-and-Interior-Designers-Happiest-Hour into db.events!
# Inserted meetup-group-dKFwKaix into db.events!
# Inserted OrlandoStartup into db.events!
# Inserted Art-Bash-Studio into db.events!
# Inserted Gallery-One-Artists-First-Friday-Open-House into db.events!
# Inserted Gallery-One-Artists-Artist-Reception-Open-House into db.events!
# Inserted Gallery-One-Artists-Meetup into db.events!
# Inserted Midwest-Artist-Network-Art-Supporting-Arts-Meetup into db.events!
# Inserted Paint-Over-the-Rainbow into db.events!
# Inserted tricitiessketchclub into db.events!
# Inserted Decorating-and-Interior-Design into db.events!
# Inserted Madison-Artists-Connection into db.events!
# Inserted The-Shop-Rapid-City into db.events!
# Inserted Miami-Valley-Theater-and-Arts-Club into db.events!
# Inserted Creative-And-Collective-Collaborations into db.events!
# Inserted Open-Mic-Poetry-Nite-at-the-V into db.events!
# Inserted Naples-Fine-Arts-Meetup into db.events!
# Inserted Wild-at-HeART-Boone-Meetup into db.events!
# Inserted West-Central-Ohio-Storytellers into db.events!
# Inserted Milwaukee-Sketch-Club into db.events!
# Inserted Charlotte-Art-and-Music-Lovers into db.events!
# Inserted charlotteartleague into db.events!
# Inserted MN-Museumgoers-Meetup into db.events!
# Inserted Sugar-Skull-Guided-Painting-and-Wine-Workshop into db.events!
# Inserted Improv-for-Seniors into db.events!
# Inserted Self-Expression-of-Charlotte into db.events!
# Inserted Queen-City-Art-Group into db.events!
# Inserted Queen-City-Urban-Art-Showcase into db.events!
# Inserted BoomInCLT into db.events!
# Inserted Charlotte-Artisans-Makers-and-Entrepreneurs into db.events!
# Inserted Waxhaw-Paint-and-Sip-Meetup into db.events!
# Inserted Cape-Canaveral-Fine-Arts-Meetup into db.events!
# Inserted Lacanian-Psychoanalysis-Readings-and-Propositions into db.events!
# Inserted Independent-Content-Creators into db.events!
# Inserted BossBabesAndBrews into db.events!
# Inserted museum-99 into db.events!
# Inserted Creative-SoulCraft into db.events!
# Inserted Woodbury-SoulPlay-Visual-Journaling-Meetup into db.events!
# Inserted Golden-Valley-Painters into db.events!
# Inserted Twin-Cities-En-Plein-Air into db.events!
# Inserted Doodle-Dudes-USA-MINNEAPOLIS-MN into db.events!
# Inserted Actors-Writers-Meetup into db.events!
# Inserted IdeaEcos into db.events!
# Inserted Held2Gether-Creativity-Instigators-for-Fun-and-Profit into db.events!
# Inserted Sumter-Painting-Meetup into db.events!
# Inserted Drinkable-Arts-Coffee-and-creativity-at-C3 into db.events!
# Inserted Port-Washington-Plein-Air-Painting-Meetup into db.events!
# Inserted Vetreprenuers into db.events!
# Inserted Kalamazoo-Art-Meetup into db.events!
# Inserted Center-for-Faith-the-Arts into db.events!
# Inserted Mount-Pleasant-The-Artists-Way-Meetup into db.events!
# Inserted Mount-Pleasant-Artists-Way-Meetup into db.events!
# Inserted Columbus-Comic-Creators-Community into db.events!
# Inserted Cbus-It-Meetup into db.events!
# Inserted outstate-experiment into db.events!
# Inserted Artist-Connect into db.events!
# Inserted Storytelling-True-Story-SLAM-Night-Meetup into db.events!
# Inserted Salt-Lake-City-Sketchbooks into db.events!
# Inserted Clean-Date-Night-at-the-Studio into db.events!
# Inserted Henderson-Gourd-Group into db.events!
# Inserted Charleston-Improv-Practice-Group into db.events!
# Inserted Pickerington-Cartoonists-Meetup into db.events!
# Inserted VeRaCity-360-Visionary-Art-House into db.events!
# Inserted 3d-modelers into db.events!
# Inserted The-Artists-Way-2018 into db.events!
# Inserted Asteria-Arts-Meetup into db.events!
# Inserted Salt-Lake-City-Flash-Mobs-etc into db.events!
# Inserted Franklin-County-Recreation-Meetup into db.events!
# Inserted Westerville-Art-League-Meetup into db.events!
# Inserted Moment3D-Guest-Workshops into db.events!
# Inserted MUSEatDelphi into db.events!
# Inserted Las-Vegas-Outdoor-Artists into db.events!
# Inserted Beauty-from-the-Soul into db.events!
# Inserted Desert-Plein-Air-Painters into db.events!
# Inserted Clark-County-Artists-Guild-of-Las-Vegas into db.events!
# Inserted Intro-to-Acting into db.events!
# Inserted Intro-to-VO into db.events!
# Inserted The-Digital-Craftsmen-Workshop-Meetup into db.events!
# Inserted Grand-Haven-Art-Meetup into db.events!
# Inserted Winston-Salem-Bonsai-Meetup into db.events!
# Inserted Las-Vegas-Art-Music-and-Friends-Meetup into db.events!
# Inserted The-New-Studio-for-the-Visual-Arts into db.events!
# Inserted The-StArt-Program-Connecting-Artist-Inspiring-Communities into db.events!
# Inserted Adventures-with-creative-minds into db.events!
# Inserted Las-Vegas-The-Artists-Way-Meetup into db.events!
# Inserted South-Florida-Writers-and-Other into db.events!
# Inserted Juuuicy into db.events!
# Inserted Art-and-Sailing-Retreat-Greek-Islands-2017 into db.events!
# Inserted West-Palm-Beach-Improv-Meetup into db.events!
# Inserted Backyard-for-the-arts into db.events!
# Inserted Boca-Raton-Society-of-American-Magicians-Meetup into db.events!
# Inserted spiritualexplorers into db.events!
# Inserted Juicy-Creatives-Studio into db.events!
# Inserted Boca-Raton-Conscious-Creators-Meetup into db.events!
# Inserted South-Florida-Zentangle-Classes into db.events!
# Inserted Bourdain into db.events!
# Inserted Creative-Playground-Screenwriters-Actors-Filmmakers into db.events!
# Inserted Learn-Deerfield-Beach-History into db.events!
# Inserted meetup-group-UxVKbXGJ into db.events!
# Inserted Wednesday-Afternoon-Drawing-Series into db.events!
# Inserted Learn-to-Draw-at-Boca-Raton-Community-Center into db.events!
# Inserted Living-Life-Artfully-Art-Meetup into db.events!
# Inserted Miami-Night-Shows into db.events!
# Inserted Miami-Beach-Culture-Vultures-Meetup-for-40s into db.events!
# Inserted Hollywood-Fine-Arts-Meetup into db.events!
# Inserted Miami-Ceramics-and-Pottery-Meet-Up-Group into db.events!
# Inserted Artist-Entrepreneur into db.events!
# Inserted Dr-Sketchys-Anti-Art-School-South-Florida into db.events!
# Inserted miamicreativitycircle into db.events!
# Inserted meetup-group-NXcfiIZd into db.events!
# Inserted Discovering-Creativity-at-Midlife-and-Beyond into db.events!
# Inserted Actors-Group into db.events!
# Inserted southfloridaartists into db.events!
# Inserted Graphic-Artist-Guild-Southern-Region-Ft-Lauderdale into db.events!
# Inserted TRAX-Art-Studios-Painting-Classes-and-Fun-Art-Events into db.events!
# Inserted Connect-and-Create-with-SoulCollage into db.events!
# Inserted Fort-Lauderdale-Improv-Meetup into db.events!
# Inserted Painting-with-Canvas-Fiesta into db.events!
# Inserted Wine-and-Canvas-At-The-Mod-Wine-Bar into db.events!
# Inserted Fort-Lauderdale-Film-Acting-Meetup into db.events!
# Inserted Grand-Rapids-Art-Meetup into db.events!
# Inserted Artistic-Interiors into db.events!
# Inserted South-Florida-Pottery-Painting into db.events!
# Inserted wynwoodgraffitilessons into db.events!
# Inserted Wynwood-Shop-Wood-Carving-Workshop into db.events!
# Inserted Ceramics-for-a-cause into db.events!
# Inserted Hollywood-Fine-Arts-Meetup-2 into db.events!
# Inserted Miami-Theater-Meetup into db.events!
# Inserted Toledo-Art-Fans-Meetup into db.events!
# Inserted Toledo-Theatre-Lovers into db.events!
# Inserted Wild-Horses-Theatrical-Players-for-Vegans-with-PTSD-Trauma into db.events!
# Inserted Lets-Make-a-Musical-Somewhere-in-Miami into db.events!
# Inserted HOMESCHOOLING-ENRICHMENT-ART into db.events!
# Inserted Afro-Art-Beats into db.events!
# Inserted TheLittleHavanaGroup into db.events!
# Inserted TheWynwoodGroup into db.events!
# Inserted Origins-Art-Musicians-Wine-Appetizers into db.events!
# Inserted Grace-Arts-Florida-Meetup into db.events!
# Inserted Wynwood-Shop into db.events!
# Inserted Miami-Magicians into db.events!
# Inserted miarug into db.events!
# Inserted MiamiArts into db.events!
# Inserted soul-art into db.events!
# Inserted ART-PLAY into db.events!
# Inserted Friends-of-The-Bass-Museum-of-Art into db.events!
# Inserted Lastella-Acting-Studio into db.events!
# Inserted Plein-Air-Painting-in-Southwest-Virginia into db.events!
# Inserted Michigan-Shakespeare-Meetup into db.events!
# Inserted GO-Create-in-Ann-Arbor into db.events!
# Inserted meetup-group-ZBIhKGxY into db.events!
# Inserted meetup-group-siXweAuD into db.events!
# Inserted Surprise-Farm-Retreat-Center into db.events!
# Inserted Santee-Open-Mic-Meetup into db.events!
# Inserted Canton-Soul-Art-Meetup into db.events!
# Inserted PlymouthArtAndPottery into db.events!
# Inserted Fargo-Art-Meetup into db.events!
# Inserted GoBeWrite into db.events!
# Inserted art-386 into db.events!
# Inserted Metro-Detroit-Art-Talks into db.events!
# Inserted Creative-Group-for-People-with-Awesome-Ideas into db.events!
# Inserted Eclectic-Arts-Entertainment-Industry-Networking into db.events!
# Inserted Museums-Meetup-Triangle-Area into db.events!
# Inserted Durham-Draws into db.events!
# Inserted Nights-Out-at-Lambs-Players-Theatre into db.events!
# Inserted Cary-Durham-Artists-Way into db.events!
# Inserted SanDiegoArtCollectors into db.events!
# Inserted Muse-Finder-For-Art into db.events!
# Inserted sandiegocabaretdancearts into db.events!
# Inserted R-O-C-s-Therapeutic-Painting-Events into db.events!
# Inserted San-Diego-Film-and-Video-Production-Meetup into db.events!
# Inserted San-Diego-Burlesque-Meetup into db.events!
# Inserted San-Diego-3D-Printing into db.events!
# Inserted Method-Acting-Psychodrama-Training-collective-theatre into db.events!
# Inserted San-Diego-Pass-Members-Club into db.events!
# Inserted Creating-Space-Sparking-Creativity-and-Joy into db.events!
# Inserted meetup-group-HmbKMdya into db.events!
# Inserted Free-Improv-Workshop-at-The-National-Comedy-Theatre into db.events!
# Inserted meetup-group-lYZNdiYw into db.events!
# Inserted TheArtistsWaySD into db.events!
# Inserted SanDiegoFilmAndArtCabal into db.events!
# Inserted Point-Loma-Playhouse-Players-Meetup into db.events!
# Inserted SDCulture into db.events!
# Inserted Exploring-San-Diegos-History into db.events!
# Inserted Lets-Paint-Rocks into db.events!
# Inserted Durham-Art-Guild into db.events!
# Inserted Durham-Mixed-Media-Artists into db.events!
# Inserted The-Krewe-of-Moonwatchers into db.events!
# Inserted Durham-Spolin-Theater-Games-Meetup into db.events!
# Inserted The-Triangle-Animators into db.events!
# Inserted Gallery-On-The-Go-with-Brigitte into db.events!
# Inserted 13-week-workshop-The-Artists-Way-Big-Magic into db.events!
# Inserted winstitute into db.events!
# Inserted Raleigh-Voice-Over-Talent-Meetup into db.events!
# Inserted Triangle-Plein-Air-Painters into db.events!
# Inserted Spoonful-Season-Auditions into db.events!
# Inserted Meet-And-Paint into db.events!
# Inserted Chitter-Chatter-Sip-And-Splatter into db.events!

# %% [markdown]
# # Find the attendees for a particular event

# %%
req = requests.get('https://api.meetup.com/Florida-MUFON-UFO-Research-and-Investigations/events/88793112/rsvps?\
                    key={}'.format(key))

#Insert the attendees into their own database.
id_data = json.loads(req.text)

#get unique identifiers out
collection.distinct('member.id')
# Out:
# [7385260, 26274872, 71777132, 62218232, 16899141, 56597972, 12450926]

# %% [markdown]
# # Remove the groups for which events already done.

# %%
f = open('new_groups.txt', 'r')
new_groups_done = f.read().replace('"', '').replace(",", "").splitlines()
f.close()

# get total list of groups from meet-ups.groups
# all_groups = set(collection.distinct('urlname'))

# # list of usernames in groups and not in groups_done
# groups_not_done = [group for group in all_groups if group not in groups_done]

# f= open("groups_not_done.txt","w+")
# f.write(str(groups_not_done))

# f = open('groups_not_done.txt', 'r')
# groups_not_done = f.read().replace("'", '').replace(" ", '').split(',')
# f.close()

# %% [markdown]
# # Metacategories
#
# There are 33 categories, but only 24 meta-categories. Categories are merged into metacategories; for example, New Age & Spirituality, Paranormal, and Religion and Beliefs are all put into Beliefs.
#
# So metacategories is not likely to be a helpful category.

# %%
meta_categories = [[element['id'],element['name'], element['category_ids']] for element in collection.distinct('meta_category')]

pprint(meta_categories)
# Out:
# [[132, 'Beliefs', [22, 24, 28]],
#  [122, 'Arts', [1]],
#  [212, 'Language & Culture', [16]],
#  [272, 'Social', [31]],
#  [583, 'Film', [20]],
#  [162, 'Food & Drink', [10]],
#  [292, 'Tech', [34]],
#  [532, 'Hobbies & Crafts', [15]],
#  [552, 'Movements', [4, 13]],
#  [302, 'Health & Wellness', [14, 33]],
#  [585, 'LGBTQ', [12]],
#  [522, 'Career & Business', [2]],
#  [582, 'Writing', [36]],
#  [562, 'Learning', [6]],
#  [512, 'Music', [21]],
#  [242, 'Outdoors & Adventure', [3, 23]],
#  [542, 'Dance', [5]],
#  [182, 'Sci-Fi & Games', [11, 29]],
#  [222, 'Book Clubs', [18]],
#  [232, 'Family', [25]],
#  [262, 'Photography', [27]],
#  [282, 'Sports & Fitness', [9, 32]],
#  [584, 'Fashion & Beauty', [8]],
#  [252, 'Pets', [26]]]

# %% [markdown]
# # Create New MongoDB with categoryID for each group

# %%
# Purpose: Need to get the different categories
# But the events db doesn't have category IDs. 
  
def make_mongo_db_with_category_id_for_group():  
    # create a new mongo collection that has category_id for every 10th group.
    for group in new_groups_done[2::10]:
        try:
            cat_id = db.groups.find_one({'urlname' : group})['category']['id']
            print(group, cat_id)
            categories.insert_one({'group' : group, 
                                   'category_id' : cat_id})
        except:
            print('Something went wrong')

make_mongo_db_with_category_id_for_group()

# %% [markdown]
# # Use category_per_group collection to get 100 groups per category

# %%
def create_list_of_groups_per_category():
    # find distinct categories in groups_per_category
    categories = db['category_per_group'].distinct('category_id')
    cat_group = []
    for category in categories:
        #find groups for said category
        cat_cursor = db['category_per_group'].find({'category_id': category}).limit(100)
        cat_group += [[category, group['group']] for group in cat_cursor]
    return cat_group
        
hundred_groups_per_cat = create_list_of_groups_per_category()
# Out:
# 3129

# %%
hundred_groups_per_cat[1][1]
# Out:
# 'FRINGEnewjersey'

# %%
db.attendees.find_one({'urlname':'colorado-ghost-hunters-group'}) is None
# Out:
# False

# %% [markdown]
# We have 191,651 groups.
#
# Dict has event: number
#
# 1. Filter event by key > 50 - turn into list.
# 2. The function will take the urlname > find_all in events that match that urlname > for each of those events, do api call that gets attendees > insert that result into new mongo db.
#
# Halfway through I decide I need the groups with less than 50 events.

# %%
def pull_attendees_for_events_for_group(list_of_groups):
    '''
    For every group, we get all of their events. For every event, we get the list of attendees.
    We insert a document into the attendees collection with this information, as well as
    the date and time. 
    '''
    for group in list_of_groups:
        # If it's not already in there.
        if db.attendees_redo.find_one({'urlname':group[1]}) is None:
            print('On Group:' + group[1])
            req = requests.get('https://api.meetup.com/{}/events?\
                                key={}&status=past&page=1&desc=true'.format(group[1], key))
            print(req.headers['X-RateLimit-Remaining'])
            if int(req.headers['X-Total-Count']) > 1:
                
                events = events_coll.find({'group.urlname' : group[1]})
                print(events.count())
                for event in events:
                    # Only want events that people showed up to. The host doesn't count. 
                    if event['yes_rsvp_count'] > 1:
                        req = requests.get(
                            'https://api.meetup.com/{}/events/{}/rsvps?key={}&response=yes&only=member'\
                            .format(group[1], event['id'], key))
                        time.sleep(0.2)
                        yeses = json.loads(req.text)
                        ids = [yes['member']['id'] for yes in yeses if yes['member']['event_context']['host'] != True]
                        attendees_redo.insert_one({'group' : event['group']['id'],
                                              'urlname': group[1],
                                              'event' : event['id'],
                                              'date' : event['local_date'],
                                              'time' : event['local_time'],
                                             'attendees' : ids,
                                             'category_id' : group[0]})

pull_attendees_for_events_for_group(hundred_groups_per_cat)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-16c5f2db6c6d> in <module>
#      33                                              'category_id' : group[0]})
#      34
# ---> 35 pull_attendees_for_events_for_group(hundred_groups_per_cat)
#
# <ipython-input-104-16c5f2db6c6d> in pull_attendees_for_events_for_group(list_of_groups)
#       7     for group in list_of_groups:
#       8         # If it's not already in there.
# ----> 9         if db.attendees_redo.find_one({'urlname':group[1]}) is None:
#      10             print('On Group:' + group[1])
#      11             req = requests.get('https://api.meetup.com/{}/events?\
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/collection.py in find_one(self, filter, *args, **kwargs)
#    1260
#    1261         cursor = self.find(filter, *args, **kwargs)
# -> 1262         for result in cursor.limit(-1):
#    1263             return result
#    1264         return None
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/cursor.py in _refresh(self)
#    1085
#    1086         if not self.__session:
# -> 1087             self.__session = self.__collection.database.client._ensure_session()
#    1088
#    1089         if self.__id is None:  # Query
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1561             # Don't make implicit sessions causally consistent. Applications
#    1562             # should always opt-in.
# -> 1563             return self.__start_session(True, causal_consistency=False)
#    1564         except (ConfigurationError, InvalidOperation):
#    1565             # Sessions not supported, or multiple users authenticated.
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1514
#    1515         # Raises ConfigurationError if sessions are not supported.
# -> 1516         server_session = self._get_server_session()
#    1517         opts = client_session.SessionOptions(**kwargs)
#    1518         return client_session.ClientSession(
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1547     def _get_server_session(self):
#    1548         """Internal: start or resume a _ServerSession."""
# -> 1549         return self._topology.get_server_session()
#    1550
#    1551     def _return_server_session(self, server_session, lock):
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/topology.py in get_server_session(self)
#     425                             any_server_selector,
#     426                             self._settings.server_selection_timeout,
# --> 427                             None)
#     428                 elif not self._description.readable_servers:
#     429                     self._select_servers_loop(
#
# ~/anaconda3/lib/python3.7/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     206             # came after our most recent apply_selector call, since we've
#     207             # held the lock until now.
# --> 208             self._condition.wait(common.MIN_HEARTBEAT_INTERVAL)
#     209             self._description.check_compatible()
#     210             now = _time()
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# # Analysis: For every attendee, did you come back?

# %%
def did_they_come_back():
    
    # Get list of urlnames in db.attendees
    urlnames = db.attendees.distinct('urlname')
    for urlname in urlnames:
        return db.attendees.find_one({'urlname':urlname})['category_id']
        events = db.attendees.find({'urlname':'The-Drawing-Circle-Valencia'})
        all_attendees_ever = [event['attendees'] for event in events]
        
        #turns list of lists into list.
        all_attendees_ever = [k for i in all_attendees_ever for k in i]
        
        #Counts number who have ever attended.
        all_attendees_ever_set = len(set(all_attendees_ever))
        
        #Counts their occurence, only keeps the returners.
        times_dict = Counter(all_attendees_ever)
        all_attendees_greater_than_1 = len([k for k, v in times_dict.items() if v > 1])
        percent_return = all_attendees_greater_than_1 / all_attendees_ever_set
        
        #Insert the data for each group into mongo
        db.returns_per_group.insert_one({'urlname' : urlname,
                                         'Percent_Return' : percent_return,
                                         'Category_ID': 'o'})
        
    
did_they_come_back()

# %% [markdown]
# # Next steps
#
# Remove groups that have only had 1 event.
#
# Remove groups that have < n events.
#
# How much do retention rates change over time? That would be beautiful to visualize.
#
# Especially for Austin-Texas meetup group
#
# ## To figure out category popularity
#
# * Get average number of attendees / event for every category.
#
# * Total events per category (not very helpful)
#
# * Average events / group per category.

# %%
[val for val in hundred_groups_per_cat if val[1] =='Scottish-Gay-Soul-Music-Fans']

hundred_groups_per_cat.index([21, 'Scottish-Gay-Soul-Music-Fans'])
# Out:
# 163

# %%
ssh -L localhost:8888:localhost:8888 -i "ecdoso.pem" ec2-user@ec2-52-14-250-184.us-east-2.compute.amazonaws.com
